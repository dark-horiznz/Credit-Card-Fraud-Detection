# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/content/drive/MyDrive/creditcard.csv')

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.describe().T
# Out:
#            count          mean           std         min           25%  \
# Time    284807.0  9.481386e+04  47488.145955    0.000000  54201.500000
# V1      284807.0  1.168375e-15      1.958696  -56.407510     -0.920373
# V2      284807.0  3.416908e-16      1.651309  -72.715728     -0.598550
# V3      284807.0 -1.379537e-15      1.516255  -48.325589     -0.890365
# V4      284807.0  2.074095e-15      1.415869   -5.683171     -0.848640
# V5      284807.0  9.604066e-16      1.380247 -113.743307     -0.691597
# V6      284807.0  1.487313e-15      1.332271  -26.160506     -0.768296
# V7      284807.0 -5.556467e-16      1.237094  -43.557242     -0.554076
# V8      284807.0  1.213481e-16      1.194353  -73.216718     -0.208630
# V9      284807.0 -2.406331e-15      1.098632  -13.434066     -0.643098
# V10     284807.0  2.239053e-15      1.088850  -24.588262     -0.535426
# V11     284807.0  1.673327e-15      1.020713   -4.797473     -0.762494
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(14 , 8))
sns.heatmap(data.corr() , vmin = -1 , vmax = 1  , cmap='coolwarm')
# Out:
# <Axes: >

# %%
features = []
for column in data.columns:
    if column != 'Class' and column != 'id':
        dat = np.round(data[['Class' , column]].corr().to_numpy()[0][1] , decimals = 4)
        if abs(dat) > 0.2:
            print(f"{dat} to feature {column}")
            features.append(column)
# Out:
# -0.2169 to feature V10
# -0.2606 to feature V12
# -0.3025 to feature V14
# -0.3265 to feature V17

# %%
data.hist(bins=20, figsize=(30, 30))
# Out:
# array([[<Axes: title={'center': 'Time'}>, <Axes: title={'center': 'V1'}>,
#         <Axes: title={'center': 'V2'}>, <Axes: title={'center': 'V3'}>,
#         <Axes: title={'center': 'V4'}>, <Axes: title={'center': 'V5'}>],
#        [<Axes: title={'center': 'V6'}>, <Axes: title={'center': 'V7'}>,
#         <Axes: title={'center': 'V8'}>, <Axes: title={'center': 'V9'}>,
#         <Axes: title={'center': 'V10'}>, <Axes: title={'center': 'V11'}>],
#        [<Axes: title={'center': 'V12'}>, <Axes: title={'center': 'V13'}>,
#         <Axes: title={'center': 'V14'}>, <Axes: title={'center': 'V15'}>,
#         <Axes: title={'center': 'V16'}>, <Axes: title={'center': 'V17'}>],
#        [<Axes: title={'center': 'V18'}>, <Axes: title={'center': 'V19'}>,
#         <Axes: title={'center': 'V20'}>, <Axes: title={'center': 'V21'}>,
#         <Axes: title={'center': 'V22'}>, <Axes: title={'center': 'V23'}>],
#        [<Axes: title={'center': 'V24'}>, <Axes: title={'center': 'V25'}>,
# ...

# %%
categories = list(set(data['Class']))
colors = ['blue' , 'red']
for i, category in enumerate(categories):
  category_data = [value for value, cat in zip(data['Time'], data['Class']) if cat == category]
  plt.hist(category_data, color=colors[i], label=category, alpha=0.5)
plt.legend()
plt.xlabel('Time')
plt.ylabel('Frequency')
plt.title('Histogram by Category')
plt.show()

# %%
x = data['Class'].value_counts()
plt.pie(x , labels = ['Not Fraud' , 'Fraud'], autopct='%.2f', radius = 0.9)
plt.legend(['Not Fraud' , 'Fraud'], loc ='upper right')
plt.show()

# %%
from sklearn.preprocessing import RobustScaler
new_df = data.copy()
new_df['Amount'] = RobustScaler().fit_transform(new_df['Amount'].to_numpy().reshape(-1, 1))
time = new_df['Time']
new_df['Time'] = (time - time.min()) / (time.max() - time.min())

# %%
train , test , val = new_df.iloc[:260000] , new_df.iloc[260000:280000] , new_df.iloc[280000:]
x_train , y_train = train.iloc[:,:-1].to_numpy() , train.iloc[:,-1].to_numpy()
x_test , y_test = test.iloc[:,:-1].to_numpy() , test.iloc[:,-1].to_numpy()
x_val , y_val = val.iloc[:,:-1].to_numpy() , val.iloc[:,-1].to_numpy()

# %% [markdown]
# Support Vector Classifier

# %%
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report
svc = LinearSVC(class_weight='balanced')
svc.fit(x_train, y_train)
print(classification_report(y_val, svc.predict(x_val), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00      4803
#        Fraud       1.00      0.75      0.86         4
#
#     accuracy                           1.00      4807
#    macro avg       1.00      0.88      0.93      4807
# weighted avg       1.00      1.00      1.00      4807
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %% [markdown]
# Random Forest Classifer

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(max_depth=2, n_jobs=-1)
rf.fit(x_train, y_train)
print(classification_report(y_val, rf.predict(x_val), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00      4803
#        Fraud       1.00      0.25      0.40         4
#
#     accuracy                           1.00      4807
#    macro avg       1.00      0.62      0.70      4807
# weighted avg       1.00      1.00      1.00      4807

# %%
# !pip install snapml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 2.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# Snap ML Random Forest

# %%
from snapml import RandomForestClassifier as SnapRandomForestClassifier
model = SnapRandomForestClassifier(max_depth=3, n_estimators=100, n_jobs=4, random_state=42, use_histograms=True)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(classification_report(y_test, y_pred, target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00     19983
#        Fraud       0.89      0.47      0.62        17
#
#     accuracy                           1.00     20000
#    macro avg       0.94      0.74      0.81     20000
# weighted avg       1.00      1.00      1.00     20000

# %% [markdown]
# Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc = GradientBoostingClassifier(n_estimators=50, learning_rate=1.0, max_depth=1, random_state=0)
gbc.fit(x_train, y_train)
print(classification_report(y_val, gbc.predict(x_val), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00      4803
#        Fraud       1.00      0.75      0.86         4
#
#     accuracy                           1.00      4807
#    macro avg       1.00      0.88      0.93      4807
# weighted avg       1.00      1.00      1.00      4807

# %% [markdown]
# ANN Model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint

shallow_nn = Sequential()
shallow_nn.add(InputLayer((x_train.shape[1],)))
shallow_nn.add(Dense(10, 'relu'))
shallow_nn.add(BatchNormalization())
shallow_nn.add(Dense(2, 'relu'))
shallow_nn.add(BatchNormalization())
shallow_nn.add(Dense(1, 'sigmoid'))

checkpoint = ModelCheckpoint('shallow_nn', save_best_only=True)
shallow_nn.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
with tf.device('/device:GPU:0'):
  shallow_nn.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=4, callbacks=checkpoint)
# Out:
# Epoch 1/4
# 8125/8125 [==============================] - 73s 8ms/step - loss: 0.0472 - accuracy: 0.9888 - val_loss: 0.0036 - val_accuracy: 0.9996
# Epoch 2/4
# 8125/8125 [==============================] - 57s 7ms/step - loss: 0.0034 - accuracy: 0.9993 - val_loss: 0.0052 - val_accuracy: 0.9996
# Epoch 3/4
# 8125/8125 [==============================] - 49s 6ms/step - loss: 0.0033 - accuracy: 0.9994 - val_loss: 0.0049 - val_accuracy: 0.9996
# Epoch 4/4
# 8125/8125 [==============================] - 56s 7ms/step - loss: 0.0033 - accuracy: 0.9993 - val_loss: 0.0065 - val_accuracy: 0.9994

# %%
def neural_net_predictions(model, x):
  return (model.predict(x).flatten() > 0.5).astype(int)
neural_net_predictions(shallow_nn, x_val)
# Out:
# 151/151 [==============================] - 1s 3ms/step
# array([0, 0, 0, ..., 0, 0, 0])

# %%
print(classification_report(y_val, neural_net_predictions(shallow_nn, x_val), target_names=['Not Fraud', 'Fraud']))
# Out:
# 151/151 [==============================] - 1s 4ms/step
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00      4803
#        Fraud       0.60      0.75      0.67         4
#
#     accuracy                           1.00      4807
#    macro avg       0.80      0.87      0.83      4807
# weighted avg       1.00      1.00      1.00      4807

# %% [markdown]
# Data Augmentation

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter
counter = Counter(y_train)
print('Before', counter)
smtom = SMOTE(sampling_strategy = 'minority')
X_train_smtom, y_train_smtom = smtom.fit_resample(x_train[:40000], y_train[:40000])
counter = Counter(y_train_smtom)
print('After', counter)
# Out:
# Before Counter({0: 259529, 1: 471})
# After Counter({0: 39896, 1: 39896})

# %%
x_train = np.concatenate((x_train, X_train_smtom), axis=0)
y_train = np.concatenate((y_train, y_train_smtom), axis=0)

# %% [markdown]
# Augmented Data

# %%
counts = dict(Counter(y_train))
x = [counts[0], counts[1]]
plt.pie(x , labels = ['Not Fraud' , 'Fraud'], autopct='%.2f', radius = 0.9)
plt.legend(['Not Fraud' , 'Fraud'], loc ='upper right')
plt.show()

# %%
y_train.shape
# Out:
# (339792,)

# %%
X = np.concatenate((x_train, y_train.reshape(339792,1)), axis=1)
dat = pd.DataFrame(X, columns= data.columns)
dat.head()
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0  0.000000 -0.694242 -0.044075  1.672773  0.973366 -0.245117  0.347068
# 1  0.000000  0.608496  0.161176  0.109797  0.316523  0.043483 -0.061820
# 2  0.000006 -0.693500 -0.811578  1.169468  0.268231 -0.364572  1.351454
# 3  0.000006 -0.493325 -0.112169  1.182516 -0.609727 -0.007469  0.936150
# 4  0.000012 -0.591330  0.531541  1.021412  0.284655 -0.295015  0.071999
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0  0.193679  0.082637  0.331128  ... -0.024923  0.382854 -0.176911  0.110507
# 1 -0.063700  0.071253 -0.232494  ... -0.307377 -0.880077  0.162201 -0.561131
# 2  0.639776  0.207373 -1.378675  ...  0.337632  1.063358  1.456320 -1.138092
# 3  0.192071  0.316018 -1.262503  ... -0.147443  0.007267 -0.304777 -1.941027
# 4  0.479302 -0.226510  0.744326  ... -0.012839  1.100011 -0.220123  0.233250
#
#         V25       V26       V27       V28    Amount  Class
# ...

# %%
categories = list(set(dat['Class']))
colors = ['blue' , 'red']
for i, category in enumerate(categories):
  category_data = [value for value, cat in zip(dat['Time'], dat['Class']) if cat == category]
  plt.hist(category_data, color=colors[i], label=category, alpha=0.5)
plt.legend()
plt.xlabel('Time')
plt.ylabel('Frequency')
plt.title('Histogram by Category')
plt.show()

# %% [markdown]
# Augmented SVM

# %%
svc_aug = LinearSVC(class_weight='balanced')
svc_aug.fit(x_train, y_train)
print(classification_report(y_val, svc_aug.predict(x_val), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00      4803
#        Fraud       0.50      0.25      0.33         4
#
#     accuracy                           1.00      4807
#    macro avg       0.75      0.62      0.67      4807
# weighted avg       1.00      1.00      1.00      4807
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %% [markdown]
# Augmented Forest

# %%
model_aug = SnapRandomForestClassifier(max_depth=3, n_estimators=100, n_jobs=4, random_state=42, use_histograms=True)
model_aug.fit(x_train, y_train)
y_pred = model_aug.predict(x_test)
print(classification_report(y_test, y_pred, target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00     19983
#        Fraud       0.62      0.59      0.61        17
#
#     accuracy                           1.00     20000
#    macro avg       0.81      0.79      0.80     20000
# weighted avg       1.00      1.00      1.00     20000

# %% [markdown]
# Augmented Gradient Boost

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(max_depth=2, n_jobs=-1)
rf.fit(x_train, y_train)
print(classification_report(y_val, rf.predict(x_val), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00      4803
#        Fraud       1.00      0.75      0.86         4
#
#     accuracy                           1.00      4807
#    macro avg       1.00      0.88      0.93      4807
# weighted avg       1.00      1.00      1.00      4807

# %%
gbc_aug = GradientBoostingClassifier(n_estimators=50, learning_rate=1.0, max_depth=1, random_state=0)
gbc_aug.fit(x_train, y_train)
print(classification_report(y_val, gbc_aug.predict(x_val), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00      4803
#        Fraud       0.50      0.25      0.33         4
#
#     accuracy                           1.00      4807
#    macro avg       0.75      0.62      0.67      4807
# weighted avg       1.00      1.00      1.00      4807

# %% [markdown]
# Augmented ANN

# %%
shallow_nn.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
with tf.device('/device:GPU:0'):
  shallow_nn.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=4, callbacks=checkpoint)
# Out:
# Epoch 1/4
# 10619/10619 [==============================] - 65s 6ms/step - loss: 0.0280 - accuracy: 0.9921 - val_loss: 0.0023 - val_accuracy: 0.9998
# Epoch 2/4
# 10619/10619 [==============================] - 83s 8ms/step - loss: 0.0076 - accuracy: 0.9986 - val_loss: 0.0028 - val_accuracy: 0.9998
# Epoch 3/4
# 10619/10619 [==============================] - 85s 8ms/step - loss: 0.0060 - accuracy: 0.9990 - val_loss: 0.0027 - val_accuracy: 0.9996
# Epoch 4/4
# 10619/10619 [==============================] - 57s 5ms/step - loss: 0.0059 - accuracy: 0.9990 - val_loss: 0.0026 - val_accuracy: 0.9998

# %%
def neural_net_predictions(model, x):
  return (model.predict(x).flatten() > 0.5).astype(int)
neural_net_predictions(shallow_nn, x_val)
# Out:
# 151/151 [==============================] - 0s 2ms/step
# array([0, 0, 0, ..., 0, 0, 0])

# %%
print(classification_report(y_val, neural_net_predictions(shallow_nn, x_val), target_names=['Not Fraud', 'Fraud']))
# Out:
# 151/151 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00      4803
#        Fraud       1.00      0.75      0.86         4
#
#     accuracy                           1.00      4807
#    macro avg       1.00      0.88      0.93      4807
# weighted avg       1.00      1.00      1.00      4807
